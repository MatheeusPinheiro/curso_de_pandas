# %%
import pandas as pd

# %%
# Lendo as planilhas 
vendas_df = pd.read_excel(r"Arquivos\Vendas_Merge.xlsx")
vendedores_df = pd.read_excel(r"Arquivos\Vendedores_Merge.xlsx")
produtos_df = pd.read_excel(r"Arquivos\Produtos_Merge.xlsx")

display(produtos_df)

# %%
#Merge - Uniu através de um denominador em comum
vendas_df = vendas_df.merge(vendedores_df)
display(vendas_df)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         27264      100345 2023-01-07                   4          150.50
# 2         27264      100208 2023-01-11                   6           46.90
# 3         27264      100244 2023-01-20                   9          146.14
# 4         27264      100345 2023-01-22                   6          150.50
# 5         21732      100359 2023-01-02                   2           69.99
# 6         21732      100411 2023-01-08                   4          248.73
# 7         21732      100226 2023-01-12                   2           41.90
# 8         21732      100001 2023-01-15                   8           89.90
# 9         21732      100105 2023-01-18                   7          153.40
# 10        21732      100411 2023-01-23                   4          248.73
# ...

# %%
#Merge - Uniu através de um denominador em comum
vendas_df = vendas_df.merge(produtos_df)
display(vendas_df)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         37579      100482 2023-01-16                   4           89.99
# 2         27264      100345 2023-01-07                   4          150.50
# 3         27264      100345 2023-01-22                   6          150.50
# 4         27264      100208 2023-01-11                   6           46.90
# 5         21732      100208 2023-01-26                   5           46.90
# 6         27264      100244 2023-01-20                   9          146.14
# 7         21164      100244 2023-01-05                   6          146.14
# 8         21732      100359 2023-01-02                   2           69.99
# 9         20437      100359 2023-01-17                   7           69.99
# 10        21732      100411 2023-01-08                   4          248.73
# ...

# %%
#Merge - Uniu através de um denominador em comum
vendas_df = vendas_df.merge(produtos_df)
vendas_df = vendas_df.merge(vendedores_df)
display(vendas_df)
# Out:
#     Id Vendedor  ID Produto Data Venda  Quantidade Vendida  Valor Unitário  \
# 0         27264      100482 2023-01-01                   8           89.99
# 1         27264      100345 2023-01-07                   4          150.50
# 2         27264      100345 2023-01-22                   6          150.50
# 3         27264      100208 2023-01-11                   6           46.90
# 4         27264      100244 2023-01-20                   9          146.14
# 5         37579      100482 2023-01-16                   4           89.99
# 6         21732      100208 2023-01-26                   5           46.90
# 7         21732      100359 2023-01-02                   2           69.99
# 8         21732      100411 2023-01-08                   4          248.73
# 9         21732      100411 2023-01-23                   4          248.73
# 10        21732      100226 2023-01-12                   2           41.90
# ...

# %%
resumo_df = vendas_df[['Vendedor', 'Produto', 'Total Vendas']]
display(resumo_df)
